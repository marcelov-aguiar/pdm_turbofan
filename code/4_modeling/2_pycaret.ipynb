# %% [markdown]
# Objetivo desse notebook é avaliar, a partir dos resultados do Pycaret, os possíveis modelos a serem testados durante a modelagem.
#
# OBS: Recomenda-se criar um ambiente virtual exclusivo para instalar o Pycaret para evitar conflitos com as versões deste projeto.

# %%
import numpy as np
import pandas as pd
import os
import sys
import logging
import pycaret.regression as reg

# %%
# region: parâmetros necessários para uso do logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
console_format = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
console_handler = logging.StreamHandler()
console_handler.setFormatter(console_format)
console_handler.setLevel(logging.INFO)
logger.addHandler(console_handler)
# endregion
base_path = sys.path[0]

path_manipulate_data = os.path.abspath(os.path.join(base_path, "..", "0_utils"))

sys.path.append(str(path_manipulate_data))

from class_manipulate_data import ManipulateData

manipulate_data = ManipulateData()
path_preprocessing_output = manipulate_data.get_path_preprocessing_output()

# %%
logger.info("Definindo as entradas, a saída e o equipamento.")

input_model = ['setting_1', 'setting_2', 'sensor_2', 'sensor_3',
       'sensor_4', 'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11',
       'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17',
       'sensor_20', 'sensor_21']

output_model = ['RUL']

equipment_name = 'FD001'
# Out:
# __main__ - INFO - Definindo as entradas, a saída e o equipamento.

# %%
logger.info("Lendo os dados de treino.")
path_dataset_train = os.path.join(path_preprocessing_output, f"train_{equipment_name}.csv")

df_train = pd.read_csv(path_dataset_train)

logger.info("Lendo os dados de teste.")
path_dataset_test = os.path.join(path_preprocessing_output, f"test_{equipment_name}.csv")

df_test = pd.read_csv(path_dataset_test)
# Out:
# __main__ - INFO - Lendo os dados de treino.
# __main__ - INFO - Lendo os dados de teste.

# %%
# concateando os dados de treino e teste

df_train = df_train.drop(columns=["unit_number", "time"])
df_test = df_test.drop(columns=["unit_number", "time"])

df_data = pd.concat([df_train, df_test])

# %%
df_data = df_data[input_model + output_model]

# %%
reg1 = reg.setup(df_data,
                 target=output_model[0],
                 train_size=0.8,
                 normalize=True,
                 normalize_method='zscore',
                 experiment_name='Turbofan')
# Out:
# <style type="text/css">
# #T_fa962_row27_col1, #T_fa962_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fa962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa962_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fa962_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa962_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_fa962_row0_col1" class="data row0 col1" >4497</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa962_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fa962_row1_col1" class="data row1 col1" >RUL</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa962_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_fa962_row2_col1" class="data row2 col1" >(33727, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa962_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_fa962_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa962_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_fa962_row4_col1" class="data row4 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa962_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_fa962_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa962_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_fa962_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa962_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_fa962_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa962_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_fa962_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa962_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_fa962_row9_col1" class="data row9 col1" >(26981, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fa962_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_fa962_row10_col1" class="data row10 col1" >(6746, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fa962_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_fa962_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fa962_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_fa962_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fa962_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_fa962_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fa962_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_fa962_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fa962_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_fa962_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fa962_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_fa962_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fa962_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_fa962_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fa962_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_fa962_row18_col1" class="data row18 col1" >Turbofan</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fa962_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_fa962_row19_col1" class="data row19 col1" >fbf6</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fa962_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_fa962_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fa962_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_fa962_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fa962_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_fa962_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fa962_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_fa962_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fa962_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_fa962_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_fa962_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_fa962_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_fa962_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_fa962_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_fa962_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_fa962_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_fa962_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_fa962_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_fa962_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_fa962_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa962_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_fa962_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_fa962_row3

# %%
best_model = reg.compare_models(fold=10, sort='RMSE', exclude = ['huber'], n_select=5)
# Out:
# <style type="text/css">
# #T_0b1fb th {
#   text-align: left;
# }
# #T_0b1fb_row0_col0, #T_0b1fb_row0_col5, #T_0b1fb_row0_col6, #T_0b1fb_row1_col0, #T_0b1fb_row1_col1, #T_0b1fb_row1_col2, #T_0b1fb_row1_col3, #T_0b1fb_row1_col4, #T_0b1fb_row1_col5, #T_0b1fb_row1_col6, #T_0b1fb_row2_col0, #T_0b1fb_row2_col1, #T_0b1fb_row2_col2, #T_0b1fb_row2_col3, #T_0b1fb_row2_col4, #T_0b1fb_row3_col0, #T_0b1fb_row3_col1, #T_0b1fb_row3_col2, #T_0b1fb_row3_col3, #T_0b1fb_row3_col4, #T_0b1fb_row3_col5, #T_0b1fb_row3_col6, #T_0b1fb_row4_col0, #T_0b1fb_row4_col1, #T_0b1fb_row4_col2, #T_0b1fb_row4_col3, #T_0b1fb_row4_col4, #T_0b1fb_row4_col5, #T_0b1fb_row4_col6, #T_0b1fb_row5_col0, #T_0b1fb_row5_col1, #T_0b1fb_row5_col2, #T_0b1fb_row5_col3, #T_0b1fb_row5_col4, #T_0b1fb_row5_col5, #T_0b1fb_row5_col6, #T_0b1fb_row6_col0, #T_0b1fb_row6_col1, #T_0b1fb_row6_col2, #T_0b1fb_row6_col3, #T_0b1fb_row6_col4, #T_0b1fb_row6_col5, #T_0b1fb_row6_col6, #T_0b1fb_row7_col0, #T_0b1fb_row7_col1, #T_0b1fb_row7_col2, #T_0b1fb_row7_col3, #T_0b1fb_row7_col4, #T_0b1fb_row7_col5, #T_0b1fb_row7_col6, #T_0b1fb_row8_col0, #T_0b1fb_row8_col1, #T_0b1fb_row8_col2, #T_0b1fb_row8_col3, #T_0b1fb_row8_col4, #T_0b1fb_row8_col5, #T_0b1fb_row8_col6, #T_0b1fb_row9_col0, #T_0b1fb_row9_col1, #T_0b1fb_row9_col2, #T_0b1fb_row9_col3, #T_0b1fb_row9_col4, #T_0b1fb_row9_col5, #T_0b1fb_row9_col6, #T_0b1fb_row10_col0, #T_0b1fb_row10_col1, #T_0b1fb_row10_col2, #T_0b1fb_row10_col3, #T_0b1fb_row10_col4, #T_0b1fb_row10_col5, #T_0b1fb_row10_col6, #T_0b1fb_row11_col0, #T_0b1fb_row11_col1, #T_0b1fb_row11_col2, #T_0b1fb_row11_col3, #T_0b1fb_row11_col4, #T_0b1fb_row11_col5, #T_0b1fb_row11_col6, #T_0b1fb_row12_col0, #T_0b1fb_row12_col1, #T_0b1fb_row12_col2, #T_0b1fb_row12_col3, #T_0b1fb_row12_col4, #T_0b1fb_row12_col5, #T_0b1fb_row12_col6, #T_0b1fb_row13_col0, #T_0b1fb_row13_col1, #T_0b1fb_row13_col2, #T_0b1fb_row13_col3, #T_0b1fb_row13_col4, #T_0b1fb_row13_col5, #T_0b1fb_row13_col6, #T_0b1fb_row14_col0, #T_0b1fb_row14_col1, #T_0b1fb_row14_col2, #T_0b1fb_row14_col3, #T_0b1fb_row14_col4, #T_0b1fb_row14_col5, #T_0b1fb_row14_col6, #T_0b1fb_row15_col0, #T_0b1fb_row15_col1, #T_0b1fb_row15_col2, #T_0b1fb_row15_col3, #T_0b1fb_row15_col4, #T_0b1fb_row15_col5, #T_0b1fb_row15_col6, #T_0b1fb_row16_col0, #T_0b1fb_row16_col1, #T_0b1fb_row16_col2, #T_0b1fb_row16_col3, #T_0b1fb_row16_col4, #T_0b1fb_row16_col5, #T_0b1fb_row16_col6 {
#   text-align: left;
# }
# #T_0b1fb_row0_col1, #T_0b1fb_row0_col2, #T_0b1fb_row0_col3, #T_0b1fb_row0_col4, #T_0b1fb_row2_col5, #T_0b1fb_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0b1fb_row0_col7, #T_0b1fb_row1_col7, #T_0b1fb_row2_col7, #T_0b1fb_row3_col7, #T_0b1fb_row4_col7, #T_0b1fb_row5_col7, #T_0b1fb_row6_col7, #T_0b1fb_row7_col7, #T_0b1fb_row8_col7, #T_0b1fb_row9_col7, #T_0b1fb_row10_col7, #T_0b1fb_row11_col7, #T_0b1fb_row12_col7, #T_0b1fb_row13_col7, #T_0b1fb_row14_col7, #T_0b1fb_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0b1fb_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0b1fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b1fb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0b1fb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0b1fb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0b1fb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0b1fb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0b1fb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0b1fb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0b1fb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b1fb_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0b1fb_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0b1fb_row0_col1" class="data row0 col1" >31.2099</td>
#       <td id="T_0b1fb_row0_col2" class="data row0 col2" >1842.2973</td>
#       <td id="T_0b1fb_row0_col3" class="data row0 col3" >42.9182</td>
#       <td id="T_0b1fb_row0_col4" class="data row0 col4" >0.5918</td>
#       <td id="T_0b1fb_row0_col5" class="data row0 col5" >0.3779</td>
#       <td id="T_0b1fb_row0_col6" class="data row0 col6" >0.3355</td>
#       <td id="T_0b1fb_row0_col7" class="data row0 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_0b1fb_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0b1fb_row1_col1" class="data row1 col1" >31.4162</td>
#       <td id="T_0b1fb_row1_col2" class="data row1 col2" >1846.6454</td>
#       <td id="T_0b1fb_row1_col3" class="data row1 col3" >42.9683</td>
#       <td id="T_0b1fb_row1_col4" class="data row1 col4" >0.5909</td>
#       <td id="T_0b1fb_row1_col5" class="data row1 col5" >0.3955</td>
#       <td id="T_0b1fb_row1_col6" class="data row1 col6" >0.3515</td>
#       <td id="T_0b1fb_row1_col7" class="data row1 col7" >0.8550</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_0b1fb_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_0b1fb_row2_col1" class="data row2 col1" >31.2847</td>
#       <td id="T_0b1fb_row2_col2" class="data row2 col2" >1852.3154</td>
#       <td id="T_0b1fb_row2_col3" class="data row2 col3" >43.0359</td>
#       <td id="T_0b1fb_row2_col4" class="data row2 col4" >0.5896</td>
#       <td id="T_0b1fb_row2_col5" class="data row2 col5" >0.3717</td>
#       <td id="T_0b1fb_row2_col6" class="data row2 col6" >0.3347</td>
#       <td id="T_0b1fb_row2_col7" class="data row2 col7" >1.6340</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_0b1fb_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_0b1fb_row3_col1" class="data row3 col1" >31.4687</td>
#       <td id="T_0b1fb_row3_col2" class="data row3 col2" >1870.8277</td>
#       <td id="T_0b1fb_row3_col3" class="data row3 col3" >43.2503</td>
#       <td id="T_0b1fb_row3_col4" class="data row3 col4" >0.5855</td>
#       <td id="T_0b1fb_row3_col5" class="data row3 col5" >0.3742</td>
#       <td id="T_0b1fb_row3_col6" class="data row3 col6" >0.3363</td>
#       <td id="T_0b1fb_row3_col7" class="data row3 col7" >2.9390</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_0b1fb_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_0b1fb_row4_col1" class="data row4 col1" >35.4959</td>
#       <td id="T_0b1fb_row4_col2" class="data row4 col2" >2111.9014</td>
#       <td id="T_0b1fb_row4_col3" class="data row4 col3" >45.9522</td>
#       <td id="T_0b1fb_row4_col4" class="data row4 col4" >0.5321</td>
#       <td id="T_0b1fb_row4_col5" class="data row4 col5" >0.5393</td>
#       <td id="T_0b1fb_row4_col6" class="data row4 col6" >0.6752</td>
#       <td id="T_0b1fb_row4_col7" class="data row4 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_0b1fb_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_0b1fb_row5_col1" class="data row5 col1" >35.4956</td>
#       <td id="T_0b1fb_row5_col2" class="data row5 col2" >2111.9439</td>
#       <td id="T_0b1fb_row5_col3" class="data row5 col3" >45.9527</td>
#       <td id="T_0b1fb_row5_col4" class="data row5 col4" >0.5321</td>
#       <td id="T_0b1fb_row5_col5" class="data row5 col5" >0.5395</td>
#       <td id="T_0b1fb_row5_col6" class="data row5 col6" >0.6758</td>
#       <td id="T_0b1fb_row5_col7" class="data row5 col7" >0.5700</td>
#     </tr>
#     <tr>
#       <th id="T_0b1fb_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_0b1fb_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_0b1fb

# %%
best_model[0]
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=4497, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# # Conclusão
#
# Pode-se observar que os modelos de Boosting e de árvore foram os melhores em relação as métricas da regressão.
